# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("BostonHousing.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
input_features = df.iloc[:,:-1]
labels = df.iloc[:,-1:]

# %%
input_features.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
labels.head()
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(input_features, labels, random_state = 2, test_size = 0.2)

# %%
print(X_train.head())
print(Y_train.head())
print(X_test.head())
print(Y_test.head())
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 37   0.08014   0.0   5.96     0  0.499  5.850  41.5  3.9342    5  279
# 286  0.01965  80.0   1.76     0  0.385  6.230  31.5  9.0892    1  241
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 25   0.84054   0.0   8.14     0  0.538  5.599  85.7  4.4546    4  307
#
#      ptratio       b  lstat
# 321     19.6  396.90   6.87
# 37      19.2  396.90   8.77
# 286     18.2  341.60  12.93
# 2       17.8  392.83   4.03
# 25      21.0  303.42  16.51
#      medv
# 321  23.1
# 37   21.0
# 286  20.1
# 2    34.7
# 25   13.9
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 463   5.82115   0.0  18.10     0  0.713  6.513  89.9  2.8016   24  666
# 152   1.12658   0.0  19.58     1  0.871  5.012  88.0  1.6102    5  403
# 291   0.07886  80.0   4.95     0  0.411  7.148  27.7  5.1167    4  245
# 183   0.10008   0.0   2.46     0  0.488  6.563  95.6  2.8470    3  193
# 384  20.08490   0.0  18.10     0  0.700  4.368  91.2  1.4395   24  666
#
#      ptratio       b  lstat
# 463     20.2  393.82  10.29
# 152     14.7  343.28  12.12
# 291     19.2  396.90   3.56
# 183     17.8  396.90   5.68
# 384     20.2  285.83  30.63
#      medv
# 463  20.2
# 152  15.3
# 291  37.3
# 183  32.5
# 384   8.8

# %%
from sklearn.tree import DecisionTreeRegressor

regressior = DecisionTreeRegressor(criterion = "squared_error", max_depth = 5)

# %%
regressior.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
y_predict = regressior.predict(X_test)

# %%
from sklearn.tree import plot_tree

plot_tree(regressior)
# Out:
# [Text(0.44, 0.9, 'x[12] <= 9.725\nsquared_error = 84.57\nsamples = 404\nvalue = 22.441'),
#  Text(0.2, 0.7, 'x[5] <= 7.47\nsquared_error = 83.234\nsamples = 167\nvalue = 29.675'),
#  Text(0.08, 0.5, 'x[7] <= 1.485\nsquared_error = 43.52\nsamples = 143\nvalue = 27.085'),
#  Text(0.04, 0.3, 'squared_error = 0.0\nsamples = 5\nvalue = 50.0'),
#  Text(0.12, 0.3, 'x[5] <= 6.722\nsquared_error = 25.381\nsamples = 138\nvalue = 26.254'),
#  Text(0.08, 0.1, 'squared_error = 11.226\nsamples = 95\nvalue = 23.843'),
#  Text(0.16, 0.1, 'squared_error = 15.434\nsamples = 43\nvalue = 31.581'),
#  Text(0.32, 0.5, 'x[10] <= 19.65\nsquared_error = 41.696\nsamples = 24\nvalue = 45.108'),
#  Text(0.28, 0.3, 'x[10] <= 17.9\nsquared_error = 19.072\nsamples = 23\nvalue = 46.117'),
#  Text(0.24, 0.1, 'squared_error = 11.465\nsamples = 19\nvalue = 47.379'),
#  Text(0.32, 0.1, 'squared_error = 11.737\nsamples = 4\nvalue = 40.125'),
#  Text(0.36, 0.3, 'squared_error = -0.0\nsamples = 1\nvalue = 21.9'),
#  Text(0.68, 0.7, 'x[0] <= 5.782\nsquared_error = 22.662\nsamples = 237\nvalue = 17.344'),
#  Text(0.52, 0.5, 'x[12] <= 14.4\nsquared_error = 13.202\nsamples = 168\nvalue = 19.227'),
#  Text(0.44, 0.3, 'x[5] <= 6.848\nsquared_error = 7.393\nsamples = 88\nvalue = 21.068'),
#  Text(0.4, 0.1, 'squared_error = 5.484\nsamples = 86\nvalue = 20.851'),
#  Text(0.48, 0.1, 'squared_error = 0.36\nsamples = 2\nvalue = 30.4'),
#  Text(0.6, 0.3, 'x[0] <= 0.181\nsquared_error = 11.76\nsamples = 80\nvalue = 17.201'),
#  Text(0.56, 0.1, 'squared_error = 9.614\nsamples = 20\nvalue = 19.9'),
#  Text(0.64, 0.1, 'squared_error = 9.238\nsamples = 60\nvalue = 16.302'),
#  Text(0.84, 0.5, 'x[12] <= 19.85\nsquared_error = 16.058\nsamples = 69\nvalue = 12.761'),
#  Text(0.76, 0.3, 'x[12] <= 19.735\nsquared_error = 13.497\nsamples = 33\nvalue = 15.036'),
#  Text(0.72, 0.1, 'squared_error = 8.912\nsamples = 32\nvalue = 14.647'),
#  Text(0.8, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 27.5'),
#  Text(0.92, 0.3, 'x[4] <= 0.675\nsquared_error = 9.309\nsamples = 36\nvalue = 10.675'),
#  Text(0.88, 0.1, 'squared_error = 4.194\nsamples = 12\nvalue = 13.792'),
#  Text(0.96, 0.1, 'squared_error = 4.581\nsamples = 24\nvalue = 9.117')]

# %%
from sklearn.metrics import r2_score

print(r2_score(Y_test, y_predict))
# Out:
# 0.7170866742952553
